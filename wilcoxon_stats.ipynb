# %%
from utils.statistical_test import wilcoxon_statistical_test
import warnings
warnings.filterwarnings('ignore')
import json

def search_vs_nces_stat_tests():
    print("### Semantic Bible ###\n")
    with open('datasets/semantic_bible/Results/NCES_ConEx_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer_I64+SetTransformer_I128']['f1']['values']
    time_nces = nces['SetTransformer_I64+SetTransformer_I128']['time']['values']
    with open('datasets/semantic_bible/Results/concept_learning_results_celoe.json') as celoe_file:
        celoe = json.load(celoe_file)
    f1_celoe = celoe['F-measure']
    time_celoe = celoe['Runtime']
    _, p1 = wilcoxon_statistical_test(f1_nces, f1_celoe)
    _, p2 = wilcoxon_statistical_test(time_nces, time_celoe)
    print("\n")
    for metric, p in zip(['F1', 'RunTime'], [p1,p2]):
        print(f'On {metric} of Semantic Bible KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Mutagenesis ###\n")
    with open('datasets/mutagenesis/Results/NCES_ConEx_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer_I32+SetTransformer_I128']['f1']['values']
    time_nces = nces['SetTransformer_I32+SetTransformer_I128']['time']['values']
    with open('datasets/mutagenesis/Results/concept_learning_results_celoe.json') as celoe_file:
        celoe = json.load(celoe_file)
    f1_celoe = celoe['F-measure']
    time_celoe = celoe['Runtime']
    _, p1 = wilcoxon_statistical_test(f1_nces, f1_celoe)
    _, p2 = wilcoxon_statistical_test(time_nces, time_celoe)
    print("\n")
    for metric, p in zip(['F1', 'RunTime'], [p1,p2]):
        print(f'On {metric} of Mutagenesis KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Carcinogenesis ###\n")    
    with open('datasets/carcinogenesis/Results/NCES_ConEx_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer_I32+SetTransformer_I64+SetTransformer_I128']['f1']['values']
    time_nces = nces['SetTransformer_I32+SetTransformer_I64+SetTransformer_I128']['time']['values']
    with open('datasets/carcinogenesis/Results/concept_learning_results_evolearner.json') as evo_file:
        evo = json.load(evo_file)
    f1_evo = evo['F-measure']
    time_evo = evo['Runtime']
    _, p1 = wilcoxon_statistical_test(f1_nces, f1_evo)
    _, p2 = wilcoxon_statistical_test(time_nces, time_evo)
    print("\n")
    for metric, p in zip(['F1', 'RunTime'], [p1,p2]):
        print(f'On {metric} of Carcinogenesis KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Vicodi ###\n")    
    with open('datasets/vicodi/Results/NCES_ConEx_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer_I32+SetTransformer_I64+SetTransformer_I128']['f1']['values']
    time_nces = nces['SetTransformer_I32+SetTransformer_I64+SetTransformer_I128']['time']['values']
    with open('datasets/vicodi/Results/concept_learning_results_evolearner.json') as evo_file:
        evo = json.load(evo_file)
    f1_evo = evo['F-measure']
    time_evo = evo['Runtime']
    _, p1 = wilcoxon_statistical_test(f1_nces, f1_evo)
    _, p2 = wilcoxon_statistical_test(time_nces, time_evo)
    for metric, p in zip(['F1', 'RunTime'], [p1,p2]):
        print(f'On {metric} of Vicodi KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()

# %%
search_vs_nces_stat_tests()
# Out:
# ### Semantic Bible ###
#
# stat=32.000, p=0.063
# stat=0.000, p=0.000
#
#
# On F1 of Semantic Bible KG, p_value =  0.06267138786896245
# Probably the same distribution
#
# On RunTime of Semantic Bible KG, p_value =  5.960464477539063e-08
# * Probably different distributions *
#
# ### Mutagenesis ###
#
# stat=17.000, p=0.026
# stat=3.000, p=0.000
#
#
# On F1 of Mutagenesis KG, p_value =  0.025842854459788903
# * Probably different distributions *
#
# On RunTime of Mutagenesis KG, p_value =  5.256413325850834e-06
# * Probably different distributions *
#
# ### Carcinogenesis ###
#
# stat=496.000, p=0.000
# stat=0.000, p=0.000
#
#
# On F1 of Carcinogenesis KG, p_value =  9.306770281399292e-07
# * Probably different distributions *
#
# On RunTime of Carcinogenesis KG, p_value =  1.1920864122849158e-16
# * Probably different distributions *
#
# ### Vicodi ###
#
# stat=344.000, p=0.000
# stat=0.000, p=0.000
# On F1 of Vicodi KG, p_value =  1.7144085687985413e-12
# * Probably different distributions *
#
# On RunTime of Vicodi KG, p_value =  1.3128610014438802e-20
# * Probably different distributions *
